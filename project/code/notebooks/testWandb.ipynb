# %%
import torch
print(torch.cuda.is_available())  # Should print True
# Out:
# False

# %% [markdown]
# # Test wandb

# %%
import wandb
import random

run = wandb.init(
    entity="uliege-tennis-tracking",
    project="tennis-tracking",
    config={"lr":0.01,
           "epochs":5}
)

for i in range(5):
    wandb.log({"epoch":i, "loss":random.uniform(0.1, 1.0)})
    
wandb.finish()
# Out:
# wandb: [wandb.login()] Loaded credentials for https://api.wandb.ai from /home/andyjalloh/.netrc.
# wandb: Currently logged in as: andyjalloh (uliege-tennis-tracking) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.25.1
# Run data is saved locally in <code>/home/andyjalloh/INFO8010-1_Project/project/code/notebooks/wandb/run-20260409_090226-0078bhi0</code>
# Syncing run <strong><a href='https://wandb.ai/uliege-tennis-tracking/tennis-tracking/runs/0078bhi0' target="_blank">spring-haze-5</a></strong> to <a href='https://wandb.ai/uliege-tennis-tracking/tennis-tracking' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/uliege-tennis-tracking/tennis-tracking' target="_blank">https://wandb.ai/uliege-tennis-tracking/tennis-tracking</a>
#  View run at <a href='https://wandb.ai/uliege-tennis-tracking/tennis-tracking/runs/0078bhi0' target="_blank">https://wandb.ai/uliege-tennis-tracking/tennis-tracking/runs/0078bhi0</a>
# wandb: ERROR The nbformat package was not found. It is required to save notebook history.
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▃▅▆█</td></tr><tr><td>loss</td><td>▁▃▄▆█</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>4</td></tr><tr><td>loss</td><td>0.97709</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">spring-haze-5</strong> at: <a href='https://wandb.ai/uliege-tennis-tracking/tennis-tracking/runs/0078bhi0' target="_blank">https://wandb.ai/uliege-tennis-tracking/tennis-tracking/runs/0078bhi0</a><br> View project at: <a href='https://wandb.ai/uliege-tennis-tracking/tennis-tracking' target="_blank">https://wandb.ai/uliege-tennis-tracking/tennis-tracking</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20260409_090226-0078bhi0/logs</code>
